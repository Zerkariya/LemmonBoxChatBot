# %%
# !git clone https://github.com/THUDM/ChatGLM2-6B
# !git clone https://huggingface.co/THUDM/chatglm2-6b
# Out:
# fatal: destination path 'ChatGLM2-6B' already exists and is not an empty directory.

# %%
# %cd ChatGLM2-6B
# Out:
# C:\Users\Felix\OneDrive\文档\他人代码\LemmonBox\ChatGLM2-6B

# %%
# !pip install gradio
# !pip install -r requirements.txt
# !pip install -qU langchain
# !pip install -qU huggingface_hub
# !pip install pinecone-client
# Out:
# ...
#      --------------------------------------- 19.8/19.8 MB 36.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 195.7/195.7 kB ? eta 0:00:00
# ...
#      ------------------------------------- 471.5/471.5 kB 14.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 289.0/289.0 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 75.4/75.4 kB 4.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 323.1/323.1 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 45.7/45.7 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 59.5/59.5 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 65.7/65.7 kB ? eta 0:00:00
# ...
#      ------------------------------------- 364.0/364.0 kB 11.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.0/61.0 kB ? eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModel
class chatGLM():
    def __init__(self, model_name) -> None:
        self.tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
        self.model = AutoModel.from_pretrained(model_name, trust_remote_code=True).half().cuda().eval()
        self.history = []

    def chat(self, prompt):
        response, self.history = self.model.chat(self.tokenizer, prompt, self.history)
        return response, self.history

# %%
llm =  chatGLM(model_name="/content/drive/MyDrive/LemmonBoxGLM/chatglm2-6b")
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "你好"
response, history = llm.chat(prompt)
print("response: %s"%response)
# Out:
# response: 你好👋！我是人工智能助手 ChatGLM2-6B，很高兴见到你，欢迎问我任何问题。

# %%
response, history = llm.chat("请问如何缓解焦虑")
print(response)
# Out:
# 缓解焦虑有很多方法，以下是一些建议：
#
# 1. 深呼吸：尝试进行深呼吸来缓解焦虑，可以慢慢吸气，然后缓慢地呼出气。
#
# 2. 放松肌肉：可以通过渐进性肌肉松弛来缓解身体的紧张情绪。
#
# 3. 运动：进行一些有氧运动，如跑步、瑜伽、游泳等，可以释放身体中的压力，让身体得到放松。
#
# 4. 找到支持：与家人、朋友或心理医生交流，可以分享自己的情感和压力，得到支持和理解。
#
# 5. 规律作息：保持规律的作息，如按时睡觉、起床，可以调节身体内的生物钟，减轻焦虑。
#
# 6. 兴趣爱好：找到一些自己感兴趣的事情，可以在空闲时间做这些事情，让自己放松和快乐。
#
# 7. 改变心态：尝试将焦虑转化为积极的能量，想象自己克服了困难，并取得了成功。
#
# 请注意，不同的人可能对不同的方法有不同的反应。如果焦虑症状持续且严重，建议及时寻求心理医生的帮助。

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100, chunk_overlap=20
)
texts = "除清汤锅之外的火锅汤底一般为重油重盐，所以尽量避免单独喝汤底。在选择汤底的时候，可以选择番茄锅，菌菇锅，三鲜锅。韩式部队火锅，寿喜锅，麻辣锅以及咖喱锅都尽量避免。\n在选择蘸料的时候，应该避免一些油较多的，比如蚝油，xo酱，牛肉酱等等。建议选择酱油，醋，小米辣等一些较干净的酱料。\n菜品的选择上建议选择一份肉类（鸡肉或者鲜牛肉为首选），一份水产类（鱼、虾），避免选择丸子类的菜品，因为市面上大部分的丸子都在制作的过程中加入大量的淀粉，导致其营养成分并不高，但是热量高。淀粉类的蔬菜，比如土豆，藕片可以代替主食。非淀粉类的蔬菜，比如茼蒿、娃娃菜可以无限量摄入。豆腐类的可以选择嫩豆腐、老豆腐；油炸类的豆腐比如腐竹，响铃卷应避免。小食类的食品可以选择豆花，冰；应该避免小酥肉以及红糖糍粑"

new_texts = text_splitter.create_documents([texts])
print("new text1: ", new_texts[0].page_content, len(new_texts[0].page_content))
print()
print("new text2: ", new_texts[1].page_content, len(new_texts[1].page_content))
# Out:
# new text1:  除清汤锅之外的火锅汤底一般为重油重盐，所以尽量避免单独喝汤底。在选择汤底的时候，可以选择番茄锅，菌菇锅，三鲜锅。韩式部队火锅，寿喜锅，麻辣锅以及咖喱锅都尽量避免。 81
#
# new text2:  在选择蘸料的时候，应该避免一些油较多的，比如蚝油，xo酱，牛肉酱等等。建议选择酱油，醋，小米辣等一些较干净的酱料。 57

# %%
response, history = llm.chat("如何健康的吃火锅？")
print(response)
# Out:
# 吃火锅时，可以采取以下健康的吃法：
#
# 1. 控制食用量：火锅中的食材量相对较大，因此要控制食用量，不要吃完饱为止。
#
# 2. 食用顺序：先吃一些清淡的食材，如蔬菜、豆腐等，再吃一些肉类和海鲜等高蛋白质食材，最后再吃一些主食，如米饭、面条等。
#
# 3. 控制油盐：在食用火锅时，要注意控制油盐的摄入量，避免过多的油脂和盐对身体的负面影响。
#
# 4. 适量搭配：在火锅中的食材要适量搭配，不要放入过多的食材，以免影响口感。
#
# 5. 注意卫生：在食用火锅时要注意卫生，不要食用已经变质的食材，以免引起身体不适。
#
# 6. 控制饮酒：在食用火锅时要注意控制饮酒量，以免对身体造成负面影响。
#
# 7. 注意休息：在食用火锅后，要适当休息，缓解身体疲劳，有助于身体的恢复。
#
# 火锅虽然是一种美食，但也要注意保持健康的饮食习惯，适量食用，注意卫生和休息。

# %%
response, history = llm.chat("国内营养学界对使用semaglutide（索马鲁肽）/ozempic（司美格鲁肽）减肥什么态度？")
print(response)
# Out:
# Semaglutide 和 Ozempic 是一种常见的减肥药物，用于治疗肥胖症。在国内，这两种药物的使用也受到了营养学界的关注。
#
# 一些营养学家认为，Semaglutide 和 Ozempic 是一种有效的减肥药物，可以帮助人们控制体重，并且不会对身体健康造成负面影响。这些营养学家还指出，这两种药物在减肥过程中，可以提供一定的能量，并且可以增加身体对食物的兴趣，从而有助于人们更好地控制饮食。
#
# 然而，一些营养学家也指出，Semaglutide 和 Ozempic 可能会对某些人的身体状况造成负面影响，尤其是对于那些已经患有糖尿病或低血糖等疾病的人来说。因此，在使用这两种药物时，应该在专业医生的指导下进行，并且要注意饮食和运动习惯的改变，以避免出现不良反应。

# %%
# !pip install -qU sentence-transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
new_embeddings = HuggingFaceEmbeddings(model_name="GanymedeNil/text2vec-large-chinese",
                                    model_kwargs={'device': "cuda"})
# query_result = embeddings.embed_query("你好")
# Out:
# ...
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/GanymedeNil_text2vec-large-chinese. Creating a new one with MEAN pooling.

# %%
query_result2 = new_embeddings.embed_documents(["你好"])

# print(query_result)
print(len(query_result2))
print(query_result2[0])
# Out:
# 1
# ...

# %%
# !ls
# Out:
# api.py	     FAQ.md	    ptuning	  README.md	    utils.py
# cli_demo.py  MODEL_LICENSE  __pycache__   requirements.txt  web_demo2.py
# evaluation   openai_api.py  README_EN.md  resources	    web_demo.py

# %%
# !pip install pinecone-client openai tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.3 MB/s eta 0:00:00
# ...

# %%
import pinecone
from langchain.vectorstores import Pinecone
pinecone.init(api_key = "acc51f3e-7f9f-4cd7-81f1-f0935e6a3dc1", environment="asia-northeast1-gcp")

# %%
index_name = "demo"
if index_name not in pinecone.list_indexes():
    # we create a new index
    pinecone.create_index(
        name=index_name,
        metric='cosine',
        dimension=1024  # 1024 dim of text2vec-large-chinese
    )

# %%
food_index = "food-index"
if food_index not in pinecone.list_indexes():
  # we create a new index
    pinecone.create_index(
        name=food_index,
        metric='cosine',
        dimension=1024  # 1024 dim of text2vec-large-chinese
    )

# %% [markdown]
# ### 此时没有任何知识库的输入

# %%
index = pinecone.Index(index_name=index_name)
index.describe_index_stats()
# Out:
# {'dimension': 1024,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 12}},
#  'total_vector_count': 12}

# %% [markdown]
# ### 开始读入json文件

# %%
# %cd /content/drive/MyDrive/LemmonBoxGLM
# Out:
# /content/drive/MyDrive/LemmonBoxGLM

# %%
import json

with open("饮食知识.json", encoding='utf-8') as file:
  data = json.load(file)

# %%
import pandas as pd
import hashlib

# %%
def generate_id(text):
    text_bytes = text.encode('utf-8')
    hash_object = hashlib.sha256(text_bytes)
    hash_value = hash_object.hexdigest()
    return hash_value

# %%
# Generate unique IDs for each text
for i in data:
    text = i['提问方式/触发行为'] + ' ' + i['答案']
    i['ID'] = generate_id(text)

# Create a DataFrame
df = pd.DataFrame(data)

# Reorder the columns (optional)
df = df[['ID', '类型', '话题', '知识点', '知识内容', '提问方式/触发行为', '答案']]
# df['答案'] = df['提问方式/触发行为'] + ' ' + df['答案']
# Print the DataFrame
print(df)
# Out:
#                                                    ID  类型    话题       知识点  \
# 0   0f79d556244e3a5e63ebd93f46220d973b852ed17db08b...  食物  健康大餐        火锅
# 1   540a871850af55e39e7ff15f35a4f18cb6cfbe39180473...  食物  健康大餐        火锅
# 2   dda8947ca19929c307590a86e8e8c7bd1251ca1331c920...  食物  健康大餐        火锅
# 3   265c456efd47af701c23b78216af2e79b0323c6ffc2ae5...  食物  健康大餐        火锅
# 4   bb48710bfbe1df6d4a2983187933aaf0f47e71176a3f4f...  食物  健康大餐        火锅
# 5   296f093a3e3656d84d89a138025299a4f1fabdb0076742...  食物  健康大餐       麦当劳
# 6   af51539d89d380d0c541a0ec0bd6eaff6ea1f6ec8afa80...  食物  健康大餐       KFC
# 7   3955cdcbca093472294def845ba92470b17665fc75f3bd...  食物  健康大餐       KFC
# 8   39620d55263e152e6d156f032dd7078c7414df03f2c8a6...  食物  健康大餐  老乡鸡/大米先生
# 9   9eddb2efd50955085c4fe189d6b8ec83827c1d57806b1e...  食物  健康大餐  老乡鸡/大米先生
# 10  3c6783caffca9afe71d197c09f23e51c7b6635aeebd5f4...  食物  营养成分      优质蛋白
# 11  983eb024defda64e1ae9d3adb3f6ef539215e658a0c2eb...  食物  营养成分      优质蛋白
#
# ...

# %%
# index.delete(deleteAll='true')

# %%
print(len(df))
# Out:
# 12

# %%
from tqdm.auto import tqdm
from uuid import uuid4

batch_size = 2

texts = []
metadatas = []

for i in tqdm(range(0, len(df), batch_size)):
    # get end of batch
    i_end = min(len(df), i+batch_size)
    batch = df.iloc[i:i_end]
    # first get metadata fields for this record
    metadatas = [{
        '提问方式/触发行为': record['提问方式/触发行为'],
        '答案': record['答案']
    } for j, record in batch.iterrows()]
    # get the list of contexts / documents
    documents = batch['提问方式/触发行为']
    print(documents)

    # create document embeddings
    embeds = new_embeddings.embed_documents(documents)
    # get IDs
    ids = batch['ID']
    # add everything to pinecone
    index.upsert(vectors=zip(ids, embeds, metadatas))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# 0    如何健康的吃火锅
# 1    怎么吃火锅不会胖
# Name: 提问方式/触发行为, dtype: object
# 2    马上要去聚餐吃火锅了，我该怎么办？
# 3           为什么吃火锅会长胖？
# Name: 提问方式/触发行为, dtype: object
# 4         如何选蘸料？
# 5    减脂期可以吃麦当劳么？
# Name: 提问方式/触发行为, dtype: object
# 6        减脂期可以吃KFC么
# 7    KFC有什么热量较低的选择？
# Name: 提问方式/触发行为, dtype: object
# 8              不想在家烧菜，有别的选择吗
# 9    \n家附近有老乡鸡/大米先生，有推荐的菜品么？
# Name: 提问方式/触发行为, dtype: object
# 10    为什么要吃蛋白质？\n\n
# 11        哪些是优质蛋白质？
# Name: 提问方式/触发行为, dtype: object

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1024,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 12}},
#  'total_vector_count': 12}

# %%
ids = df['ID'].tolist()

# %%
# index.fetch(ids)

# %%
limit = 3750

def retrieve(input_query, embeddings):
  query_result = embeddings.embed_query(input_query)
  res = index.query(query_result, top_k=1, include_metadata=True)

  retrieve_contexts = [x['metadata']['答案'] for x in res['matches']]

  prompt_start = (
        "请你根据以下内容对问题作答.\n\n"+
        "内容:\n"
  )

  prompt_end = (
        f"\n\问题: {query}\回答:"
  )
  prompt = ""
  for i in range(0, len(retrieve_contexts)):
    if len("\n\n---\n\n".join(retrieve_contexts[:i])) >= limit:
            prompt = (
                prompt_start +
                "\n\n---\n\n".join(retrieve_contexts[:i-1]) +
                prompt_end
            )
            break
    elif i == len(retrieve_contexts)-1:
            prompt = (
                prompt_start +
                "\n\n---\n\n".join(retrieve_contexts) +
                prompt_end
            )

  return prompt

# %%
query = "怎么吃KFC"
r = retrieve(input_query=query, embeddings=new_embeddings)

print("以下是给模型的输入内容：")
print(r)

print("______________________________________________________________")
print("______________________________________________________________")
print("______________________________________________________________")
print("______________________________________________________________")

print("以下是模型的回答: ")
response, history = llm.chat("100g鸡腿是200卡路里。请问400g的鸡腿卡路里是多少？")
print(response)
# Out:
# 以下是给模型的输入内容：
# 请你根据以下内容对问题作答.
#
# 内容:
# KFC的低卡搭配：奥尔良鸡腿堡+无糖可乐
# 脆皮鸡腿饭（去皮）+无糖饮料
# 玉米棒+脆皮大鸡腿（去皮）+无糖饮料
# 绿灯食物：鲜蔬芙蓉汤、
# 红灯食物：蛋挞，红豆派，土豆泥，
# \问题: 怎么吃KFC\回答:
# ______________________________________________________________
# ______________________________________________________________
# ______________________________________________________________
# ______________________________________________________________
# 以下是模型的回答:
# 抱歉刚刚的回答有误，100g鸡腿是200卡路里。
#
# 那么，400g的鸡腿就是：
#
# 400 x 200 = 80,000 卡路里
#
# 所以，400g的鸡腿是80,000 卡路里。

# %%
from langchain import LLMMathChain

# %%
llm_math = LLMMathChain.from_llm(llm, verbose=True)

llm_math.run("我吃了100g鸡腿，500g面包。每100g鸡腿的热量是400卡路里，每200g面包的热量是100卡路里。请问一共多少卡路里")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-36-8fde6ebe8dd9> in <cell line: 1>()
# ----> 1 llm_math = LLMMathChain.from_llm(llm, verbose=True)
#       2
#       3 llm_math.run("我吃了100g鸡腿，500g面包。每100g鸡腿的热量是400卡路里，每200g面包的热量是100卡路里。请问一共多少卡路里")
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm_math/base.py in from_llm(cls, llm, prompt, **kwargs)
#     174         **kwargs: Any,
#     175     ) -> LLMMathChain:
# --> 176         llm_chain = LLMChain(llm=llm, prompt=prompt)
#     177         return cls(llm_chain=llm_chain, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/load/serializable.py in __init__(self, **kwargs)
#      72
#      73     def __init__(self, **kwargs: Any) -> None:
# ---> 74         super().__init__(**kwargs)
#      75         self._lc_kwargs = kwargs
#      76
#
# ...
